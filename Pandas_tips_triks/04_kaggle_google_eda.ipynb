# %% [markdown]
# # Google App Store EDA

# %% [markdown]
# # Assignment
#
# 1. Download the data
# 2. Extract data from zip file
# 3. read the data into python pandas
# 4. check each column
# 5. Define each column in MD style

# %%
# Import Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# data import 
df = pd.read_csv('./data/googleplaystore.csv')

# %%
# run automatic eda using ydata-profiling library

# Comment out these codes if you want to do auto EDA
# import ydata_profiling as ydp
# profile = ydp.ProfileReport(df)
# profile.to_file(output_file='./outpots/05_ydata_profiling_googleplaystore_eda.html')

# %%
len(df)
# Out:
# 10841

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10840 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  int64
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10841 non-null  object
#  9   Genres          10840 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10839 non-null  object
# dtypes: float64(1), int64(1), object(11)
# memory usage: 1.1+ MB

# %%
df.isnull().sum()
# Out:
# App                  0
# Category             1
# Rating            1474
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       0
# Genres               1
# Last Updated         0
# Current Ver          8
# Android Ver          2
# dtype: int64

# %%
df.columns.value_counts()
# Out:
# App               1
# Category          1
# Rating            1
# Reviews           1
# Size              1
# Installs          1
# Type              1
# Price             1
# Content Rating    1
# Genres            1
# Last Updated      1
# Current Ver       1
# Android Ver       1
# Name: count, dtype: int64

# %%
#  lets have alook on the data
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews  Size     Installs  Type Price Content Rating  \
# 0      159   19M      10,000+  Free     0       Everyone
# 1      967   14M     500,000+  Free     0       Everyone
# 2    87510  8.7M   5,000,000+  Free     0       Everyone
# 3   215644   25M  50,000,000+  Free     0           Teen
# 4      967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
# take samples from big dataset
df.sample(10)
# Out:
#                                        App            Category  Rating  \
# 5588              Ear Agent: Super Hearing       COMMUNICATION     3.7
# 8288                   McClatchy DC Bureau  NEWS_AND_MAGAZINES     4.3
# 5243        A.J. Styles HD Wallpapers 2018         PHOTOGRAPHY     NaN
# 875                               DStv Now       ENTERTAINMENT     3.9
# 1611          Vaniday - Beauty Booking App           LIFESTYLE     3.6
# 1323  Runtastic Running App & Mile Tracker  HEALTH_AND_FITNESS     4.5
# 2053            Educational Games for Kids              FAMILY     4.5
# 5454                   AP App for Android™  NEWS_AND_MAGAZINES     3.6
# 2656         OfferUp - Buy. Sell. Offer Up            SHOPPING     4.6
# 2330               Ada - Your Health Guide             MEDICAL     4.7
#
#       Reviews                Size     Installs  Type Price Content Rating  \
# 5588    42329  Varies with device   5,000,000+  Free     0       Everyone
# ...

# %%
df.describe()
# Out:
#             Rating       Reviews
# count  9367.000000  1.084100e+04
# mean      4.191513  4.441119e+05
# std       0.515735  2.927629e+06
# min       1.000000  0.000000e+00
# 25%       4.000000  3.800000e+01
# 50%       4.300000  2.094000e+03
# 75%       4.500000  5.476800e+04
# max       5.000000  7.815831e+07

# %%
df['Size']
# Out:
# 0                       19M
# 1                       14M
# 2                      8.7M
# 3                       25M
# 4                      2.8M
#                 ...
# 10836                   53M
# 10837                  3.6M
# 10838                  9.5M
# 10839    Varies with device
# 10840                   19M
# Name: Size, Length: 10841, dtype: object

# %% [markdown]
# # Assignment: Write down all the numeric variables and make them numeric?
#
# 1. size
# 2. install
# 3. price

# %%
# Method 1: Size 
df['Size'] = df['Size'].str.replace('M', '').str.replace('k', '').str.replace('Varies with device', 'NAN')
df['Size'] = df['Size'].replace("NAN", np.nan)
df['Size'] = pd.to_numeric(df['Size'], errors='coerce')

# %%
df['Size'].unique()
# Out:
# array([1.90e+01, 1.40e+01, 8.70e+00, 2.50e+01, 2.80e+00, 5.60e+00,
#        2.90e+01, 3.30e+01, 3.10e+00, 2.80e+01, 1.20e+01, 2.00e+01,
#        2.10e+01, 3.70e+01, 2.70e+00, 5.50e+00, 1.70e+01, 3.90e+01,
#        3.10e+01, 4.20e+00, 7.00e+00, 2.30e+01, 6.00e+00, 6.10e+00,
#        4.60e+00, 9.20e+00, 5.20e+00, 1.10e+01, 2.40e+01,      nan,
#        9.40e+00, 1.50e+01, 1.00e+01, 1.20e+00, 2.60e+01, 8.00e+00,
#        7.90e+00, 5.60e+01, 5.70e+01, 3.50e+01, 5.40e+01, 2.01e+02,
#        3.60e+00, 5.70e+00, 8.60e+00, 2.40e+00, 2.70e+01, 2.50e+00,
#        1.60e+01, 3.40e+00, 8.90e+00, 3.90e+00, 2.90e+00, 3.80e+01,
#        3.20e+01, 5.40e+00, 1.80e+01, 1.10e+00, 2.20e+00, 4.50e+00,
#        9.80e+00, 5.20e+01, 9.00e+00, 6.70e+00, 3.00e+01, 2.60e+00,
#        7.10e+00, 3.70e+00, 2.20e+01, 7.40e+00, 6.40e+00, 3.20e+00,
#        8.20e+00, 9.90e+00, 4.90e+00, 9.50e+00, 5.00e+00, 5.90e+00,
#        1.30e+01, 7.30e+01, 6.80e+00, 3.50e+00, 4.00e+00, 2.30e+00,
# ...

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews  Size     Installs  Type Price Content Rating  \
# 0      159  19.0      10,000+  Free     0       Everyone
# 1      967  14.0     500,000+  Free     0       Everyone
# 2    87510   8.7   5,000,000+  Free     0       Everyone
# 3   215644  25.0  50,000,000+  Free     0           Teen
# 4      967   2.8     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
# df[df.Size == 'Varies with device'].shape

# %%
# # Replace 'Varies with device' with NaN
# df['Size'] = df['Size'].replace('Varies with device', np.nan)

# # Convert 'Size' column to string data type
# df['Size'] = df['Size'].astype(str)

# # Replace 'M' and 'k' and convert to float
# df['Size'] = df['Size'].str.replace('M', 'e+6')
# df['Size'] = df['Size'].str.replace('k', 'e+3')
# df['Size'] = df['Size'].apply(lambda x: float(x)/1000)

# # Check the data type of the 'Size' column
# print(df['Size'].dtype)

# %%
df.head(2)
# Out:
#                                               App        Category  Rating  \
# 0  Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                             Coloring book moana  ART_AND_DESIGN     3.9
#
#    Reviews  Size  Installs  Type Price Content Rating  \
# 0      159  19.0   10,000+  Free     0       Everyone
# 1      967  14.0  500,000+  Free     0       Everyone
#
#                       Genres      Last Updated Current Ver   Android Ver
# 0               Art & Design   January 7, 2018       1.0.0  4.0.3 and up
# 1  Art & Design;Pretend Play  January 15, 2018       2.0.0  4.0.3 and up

# %%
df['Size'].unique()
# Out:
# array([1.90e+01, 1.40e+01, 8.70e+00, 2.50e+01, 2.80e+00, 5.60e+00,
#        2.90e+01, 3.30e+01, 3.10e+00, 2.80e+01, 1.20e+01, 2.00e+01,
#        2.10e+01, 3.70e+01, 2.70e+00, 5.50e+00, 1.70e+01, 3.90e+01,
#        3.10e+01, 4.20e+00, 7.00e+00, 2.30e+01, 6.00e+00, 6.10e+00,
#        4.60e+00, 9.20e+00, 5.20e+00, 1.10e+01, 2.40e+01,      nan,
#        9.40e+00, 1.50e+01, 1.00e+01, 1.20e+00, 2.60e+01, 8.00e+00,
#        7.90e+00, 5.60e+01, 5.70e+01, 3.50e+01, 5.40e+01, 2.01e+02,
#        3.60e+00, 5.70e+00, 8.60e+00, 2.40e+00, 2.70e+01, 2.50e+00,
#        1.60e+01, 3.40e+00, 8.90e+00, 3.90e+00, 2.90e+00, 3.80e+01,
#        3.20e+01, 5.40e+00, 1.80e+01, 1.10e+00, 2.20e+00, 4.50e+00,
#        9.80e+00, 5.20e+01, 9.00e+00, 6.70e+00, 3.00e+01, 2.60e+00,
#        7.10e+00, 3.70e+00, 2.20e+01, 7.40e+00, 6.40e+00, 3.20e+00,
#        8.20e+00, 9.90e+00, 4.90e+00, 9.50e+00, 5.00e+00, 5.90e+00,
#        1.30e+01, 7.30e+01, 6.80e+00, 3.50e+00, 4.00e+00, 2.30e+00,
# ...

# %%
# Assuming you have a DataFrame with the columns 'size', 'install', and 'price'
df = pd.read_csv('./data/googleplaystore.csv')  # Read your dataset if it's in a CSV file, for example

# Convert specific columns to numeric
df['Size'] = pd.to_numeric(df['Size'], errors='coerce')
df['Installs'] = pd.to_numeric(df['Installs'], errors='coerce')
df['Price'] = pd.to_numeric(df['Price'], errors='coerce')

# 'errors' parameter is set to 'coerce' to handle any conversion errors by setting them to NaN

# print(df)
df.sample(10)
# Out:
#                                   App             Category  Rating  Reviews  \
# 1235   OpenTable: Restaurants Near Me       FOOD_AND_DRINK     4.6    90242
# 651                     Gods by Night               DATING     NaN      104
# 2222                  Equestria Girls               FAMILY     4.3   392596
# 886                Amazon Prime Video        ENTERTAINMENT     4.2   411683
# 10063                      Snes9x EX+                 GAME     4.4    70351
# 5473    AP Biology Study Guide + Quiz               FAMILY     4.4      105
# 4133                     Weather Live              WEATHER     4.5    76593
# 8741                     Bunny Skater                 GAME     4.2   139432
# 5129                         AG Track                TOOLS     4.1       12
# 8947                   DV Car Service  MAPS_AND_NAVIGATION     4.6       10
#
#        Size  Installs  Type  Price Content Rating  \
# 1235    NaN       NaN  Free    0.0       Everyone
# ...

# %%
# Create a DataFrame with your variables
data = {
    'size': ['10', '20', '30', '40'],
    'install': [100, 200, 300, 400],
    'price': ['$50.00', '$75.50', '$99.99', '$120.25']
}

df = pd.DataFrame(data)

# Convert specific columns to numeric
df['size'] = pd.to_numeric(df['size'], errors='coerce')
df['install'] = pd.to_numeric(df['install'], errors='coerce')
df['price'] = pd.to_numeric(df['price'].str.replace('$', '').replace(',', '', regex=True), errors='coerce')

# 'errors' parameter is set to 'coerce' to handle any conversion errors by setting them to NaN

print(df)
# Out:
#    size  install   price
# 0    10      100   50.00
# 1    20      200   75.50
# 2    30      300   99.99
# 3    40      400  120.25

# %%
# to do that let's have a look on unique values
df['Size'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\ProgramData\miniconda3\envs\python_env\Lib\site-packages\pandas\core\indexes\base.py:3790, in Index.get_loc(self, key)
#    3789 try:
# -> 3790     return self._engine.get_loc(casted_key)
#    3791 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Size'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %% [markdown]
# # Assignmnet: Check that MBs are there in one KB? and how to calculate?
#
# 1. Convert KBs into M
# 2. Then remove M from all numbers
# 3. Handle `varies with device`.

# %%
df['Size'].isnull().sum()
# Out:
# 0

# %% [markdown]
# ## Install

# %%
df['Installs'].value_counts()
# Out:
# Installs
# 1,000,000+        1579
# 10,000,000+       1252
# 100,000+          1169
# 10,000+           1054
# 1,000+             908
# 5,000,000+         752
# 100+               719
# 500,000+           539
# 50,000+            479
# 5,000+             477
# 100,000,000+       409
# 10+                386
# 500+               330
# 50,000,000+        289
# 50+                205
# 5+                  82
# 500,000,000+        72
# 1+                  67
# 1,000,000,000+      58
# 0+                  14
# 0                    1
# Name: count, dtype: int64

# %% [markdown]
# # Assignment: Do it as numeric column or group into deffrint group following bining method?

# %% [markdown]
# # How to handle Price?

# %%
df['Price'].value_counts()
# Out:
# Price
# 0         10041
# $0.99       148
# $2.99       129
# $1.99        73
# $4.99        72
#           ...
# $19.90        1
# $1.75         1
# $14.00        1
# $4.85         1
# $1.04         1
# Name: count, Length: 92, dtype: int64

# %%
df['Price'].isnull().sum()
# Out:
# 0

# %% [markdown]
# ## Assignment: Remove $ sign all comuns using Pandas?

# %%
df['Type'].value_counts()
# Out:
# Type
# Free    10040
# Paid      800
# Name: count, dtype: int64
